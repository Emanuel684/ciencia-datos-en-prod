# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/base_datos_restaurantes_USA_v2.csv'
df = pd.read_csv(file_path)
df
# Out:
#        id_persona    nombre apellido  edad     genero ciudad_residencia  \
# 0      2550327378   Jackson    Gomez  31.0  Masculino             Miami
# 1      9446112038  Samantha     Soto  40.0   Femenino            Denver
# 2      3098363243     Terry    Adams  62.0   Femenino            Denver
# 3      4013002847     James  Shannon  41.0  Masculino            Boston
# 4      7372911048     Susan    Jones  49.0   Femenino         San Diego
# ...           ...       ...      ...   ...        ...               ...
# 29995  4862097674    Robert   Cortez  20.0  Masculino           Houston
# 29996  9458262482   Michael     Holt  78.0  Masculino            Denver
# 29997  3412365931   Rebecca    Henry  77.0   Femenino         San Diego
# 29998  8853079811    Tamara  Griffin  77.0   Femenino           Chicago
# 29999  4553644223    Tracey    Flynn  57.0   Femenino           Chicago
#
#       estrato_socioeconomico  frecuencia_visita  promedio_gasto_comida ocio  \
# 0                       Alto                  6                  67.51   Sí
# 1                      Medio                  2                  44.92   Sí
# 2                       Bajo                  2                   9.24   Sí
# 3                       Alto                  5                  30.74   Sí
# 4                       Bajo                  0                   0.00   No
# ...                      ...                ...                    ...  ...
# 29995                   Alto                 -3                  30.82   Sí
# 29996                   Alto                  5                  45.04   No
# 29997               Muy Alto                  7                  93.55   No
# 29998                   Bajo                  1                   6.18   Sí
# 29999                   Bajo                  1                   6.96   No
#
#       consume_licor preferencias_alimenticias membresia_premium  \
# 0                No               Vegetariano                Sí
# 1                Sí                  Mariscos                No
# 2                Sí               Vegetariano                No
# 3                Sí                    Carnes                Sí
# 4                No                    Carnes                No
# ...             ...                       ...               ...
# 29995            Sí                    Vegano                Sí
# 29996            No                  Mariscos                No
# 29997            Sí                  Mariscos                Sí
# 29998            No                      Otro                No
# 29999            Sí                    Carnes                No
#
#          telefono_contacto         correo_electronico tipo_de_pago_mas_usado  \
# 0            (830)220-1926                        NaN               Efectivo
# 1             881-476-1426                        NaN               Efectivo
# 2                      NaN        diana74@example.net               Efectivo
# 3                      NaN      scottfrey@example.com                Tarjeta
# 4             243.248.8919      glassgary@example.org                Tarjeta
# ...                    ...                        ...                    ...
# 29995                  NaN  garciagregory@example.net                Tarjeta
# 29996                  NaN        jimmy77@example.org               Efectivo
# 29997                  NaN                        NaN               Efectivo
# 29998  (243)658-6543x11668                        NaN                Tarjeta
# 29999     295.679.7926x321                        NaN               Efectivo
#
#        ingresos_mensuales
# 0                    6425
# 1                    2374
# 2                    1110
# 3                    6931
# 4                    1350
# ...                   ...
# 29995                5781
# 29996                7652
# 29997               12639
# 29998                1057
# 29999                1348
#
# [30000 rows x 17 columns]

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# - id_persona: Identificador único de la persona.
# - nombre: Nombre de pila de la persona.
# - apellido: Apellido de la persona.
# - edad: Edad de la persona en años.
# - genero: Género declarado de la persona (Femenino o Masculino)
# - ciudad_residencia: Ciudad donde reside actualmente la persona (elegida entre 10 ciudades principales de EE. UU.)
# - estrato_socioeconomico: Nivel socioeconómico aproximado (Bajo, Medio, Alto, Muy Alto).
# - frecuencia_visita: Número aproximado de visitas al mes a restaurantes.
# - promedio_gasto_comida: Gasto promedio por visita a restaurantes (USD).
# - ocio: Indica si la persona suele participar en actividades de ocio (Sí / No).
# - consume_licor: Indica si la persona suele consumir licor (Sí / No) al visitar un restaurante.
# - preferencias_alimenticias: Preferencia de dieta (Vegano, Vegetariano, Pesacado, Mariscos, etc.).
# - membresia_premium: Indica si la persona tiene membresía premium (Sí / No) en algún restaurante.
# - telefono_contacto: Número de teléfono (campo innecesario para el análisis, sirve para practicar limpieza).
# - correo_electronico: Correo electrónico de la persona.
# - tipo_de_pago_mas_usado: Método de pago más frecuente (Efectivo, Tarjeta, App, Cripto).
# - ingresos_mensuales: Ingresos mensuales estimados (USD)

# %%
df.head(20)
# Out:
#     id_persona    nombre   apellido   edad     genero ciudad_residencia  \
# 0   2550327378   Jackson      Gomez   31.0  Masculino             Miami
# 1   9446112038  Samantha       Soto   40.0   Femenino            Denver
# 2   3098363243     Terry      Adams   62.0   Femenino            Denver
# 3   4013002847     James    Shannon   41.0  Masculino            Boston
# 4   7372911048     Susan      Jones   49.0   Femenino         San Diego
# 5   1291749568     Donna      Davis   26.0   Femenino            Dallas
# 6   3592027247     Jason  Mcpherson   80.0  Masculino               NYC
# 7   8373803828     Julie      Russo   66.0   Femenino            Boston
# 8   7395628831      Mark       Hall   31.0  Masculino               NYC
# 9   5394273061      Sara       Ball   37.0   Femenino            Boston
# 10  3040296770  Brittany   Mcmillan   80.0   Femenino               NYC
# 11  2603488527  Kimberly     Garcia   24.0   Femenino               NYC
# 12  5270305828   Jeffrey       Hill   70.0  Masculino               NYC
# 13  8580552734  Jennifer      Huynh  300.0   Femenino           Seattle
# 14  1885294397   Spencer   Thompson   79.0  Masculino            Denver
# 15  3456521319   Richard      Adams   61.0  Masculino           Chicago
# 16  6139475525    Andrew       Soto   18.0  Masculino             Miami
# 17  4596147581    Joseph      Jones   47.0  Masculino           Houston
# 18  6836509775     Bryan    Coleman   46.0  Masculino               NYC
# 19  9336353877      Mary    Bentley   29.0   Femenino            Boston
#
#    estrato_socioeconomico  frecuencia_visita  promedio_gasto_comida ocio  \
# 0                    Alto                  6                  67.51   Sí
# 1                   Medio                  2                  44.92   Sí
# 2                    Bajo                  2                   9.24   Sí
# 3                    Alto                  5                  30.74   Sí
# 4                    Bajo                  0                   0.00   No
# 5                    Alto                  6                  52.47   No
# 6                Muy Alto                 10                  56.11   No
# 7                Muy Alto                  9                  19.94   No
# 8                   Medio                  5                  16.17   No
# 9                    Bajo                  1                  11.35   Sí
# 10                   Bajo                  1                  12.65   Sí
# 11                  Medio                  5                  47.30   No
# 12                   Alto                  5                  42.20   Sí
# 13                   Bajo                  0                   0.00   No
# 14                   Alto                  4                   9.71   No
# 15                  Medio                  2                  23.02   Sí
# 16               Muy Alto                  9                  26.60   Sí
# 17                   Bajo                  3                  11.54   Sí
# 18                   Alto                  5                  64.54   Sí
# 19                  Medio                  2                  11.22   No
#
#    consume_licor preferencias_alimenticias membresia_premium  \
# 0             No               Vegetariano                Sí
# 1             Sí                  Mariscos                No
# 2             Sí               Vegetariano                No
# 3             Sí                    Carnes                Sí
# 4             No                    Carnes                No
# 5             Sí                    Carnes                Sí
# 6             No                    Vegano                Sí
# 7             Sí               Vegetariano                Sí
# 8             Sí               Vegetariano                No
# 9             No                    Carnes                No
# 10            Sí                    Carnes                No
# 11            Sí               Vegetariano                No
# 12            Sí               Vegetariano                Sí
# 13            No               Vegetariano                No
# 14            No                    Carnes                No
# 15            Sí               Vegetariano                No
# 16            Sí               Vegetariano                Sí
# 17            No                    Vegano                No
# 18            No                    Carnes                Sí
# 19            Sí               Vegetariano                No
#
#         telefono_contacto        correo_electronico tipo_de_pago_mas_usado  \
# 0           (830)220-1926                       NaN               Efectivo
# 1            881-476-1426                       NaN               Efectivo
# 2                     NaN       diana74@example.net               Efectivo
# 3                     NaN     scottfrey@example.com                Tarjeta
# 4            243.248.8919     glassgary@example.org                Tarjeta
# 5        976.606.6259x578      daniel28@example.com               Efectivo
# 6   001-327-542-1940x4789     bcastillo@example.org               Efectivo
# 7                     NaN                       NaN               Efectivo
# 8                     NaN        kara70@example.com                    App
# 9       563-346-4749x6591    smithstacy@example.com               Efectivo
# 10   +1-881-859-5881x2368  romeroangela@example.org               Efectivo
# 11                    NaN        fsmith@example.com                Tarjeta
# 12           332-647-0730  ramirezstacy@example.com                    App
# 13                    NaN      xschmidt@example.net               Efectivo
# 14                    NaN       toneill@example.com                    App
# 15          (394)853-1965                       NaN               Efectivo
# 16             2859380942       ssteele@example.net                    App
# 17       001-389-965-9131                       NaN               Efectivo
# 18                    NaN      iburnett@example.net                    App
# 19             6382528579                       NaN               Efectivo
#
#     ingresos_mensuales
# 0                 6425
# 1                 2374
# 2                 1110
# 3                 6931
# 4                 1350
# 5                 8545
# 6                10120
# 7                13456
# 8                 3350
# 9                 1197
# 10                1574
# 11                2609
# 12                3538
# 13                 931
# 14                8569
# 15                2838
# 16               13452
# 17                1351
# 18                6210
# 19                2052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_persona                 30000 non-null  int64
#  1   nombre                     30000 non-null  object
#  2   apellido                   30000 non-null  object
#  3   edad                       29899 non-null  float64
#  4   genero                     30000 non-null  object
#  5   ciudad_residencia          30000 non-null  object
#  6   estrato_socioeconomico     30000 non-null  object
#  7   frecuencia_visita          30000 non-null  int64
#  8   promedio_gasto_comida      29855 non-null  float64
#  9   ocio                       30000 non-null  object
#  10  consume_licor              30000 non-null  object
#  11  preferencias_alimenticias  28597 non-null  object
#  12  membresia_premium          30000 non-null  object
#  13  telefono_contacto          14834 non-null  object
#  14  correo_electronico         14928 non-null  object
#  15  tipo_de_pago_mas_usado     30000 non-null  object
#  16  ingresos_mensuales         30000 non-null  int64
# dtypes: float64(2), int64(3), object(12)
# memory usage: 3.9+ MB

# %%
print("Análisis descriptivo del DataFrame:")
print(df.describe(include='all'))
# Out:
# Análisis descriptivo del DataFrame:
#           id_persona   nombre apellido          edad    genero  \
# count   3.000000e+04    30000    30000  29899.000000     30000
# unique           NaN      690     1000           NaN         2
# top              NaN  Michael    Smith           NaN  Femenino
# freq             NaN      678      636           NaN     15044
# mean    5.504765e+09      NaN      NaN     49.665006       NaN
# std     2.602799e+09      NaN      NaN     23.839550       NaN
# min     1.000153e+09      NaN      NaN     -5.000000       NaN
# 25%     3.243617e+09      NaN      NaN     33.000000       NaN
# 50%     5.515865e+09      NaN      NaN     49.000000       NaN
# 75%     7.754426e+09      NaN      NaN     65.000000       NaN
# max     9.999627e+09      NaN      NaN    300.000000       NaN
#
#        ciudad_residencia estrato_socioeconomico  frecuencia_visita  \
# count              30000                  30000       30000.000000
# unique                10                      4                NaN
# top              Chicago                  Medio                NaN
# freq                5384                   9325                NaN
# mean                 NaN                    NaN           3.896133
# std                  NaN                    NaN           2.741532
# min                  NaN                    NaN          -3.000000
# 25%                  NaN                    NaN           2.000000
# 50%                  NaN                    NaN           4.000000
# 75%                  NaN                    NaN           5.000000
# max                  NaN                    NaN          10.000000
#
#         promedio_gasto_comida   ocio consume_licor preferencias_alimenticias  \
# count            29855.000000  30000         30000                     28597
# unique                    NaN      2             2                         6
# top                       NaN     No            No                    Carnes
# freq                      NaN  15094         15735                      7916
# mean                40.232383    NaN           NaN                       NaN
# std                 28.665704    NaN           NaN                       NaN
# min                  0.000000    NaN           NaN                       NaN
# 25%                 18.270000    NaN           NaN                       NaN
# 50%                 34.630000    NaN           NaN                       NaN
# 75%                 55.620000    NaN           NaN                       NaN
# max                149.980000    NaN           NaN                       NaN
#
#        membresia_premium telefono_contacto  correo_electronico  \
# count              30000             14834               14928
# unique                 2             14834               14474
# top                   No  295.679.7926x321  wbrown@example.net
# freq               17155                 1                   4
# mean                 NaN               NaN                 NaN
# std                  NaN               NaN                 NaN
# min                  NaN               NaN                 NaN
# 25%                  NaN               NaN                 NaN
# 50%                  NaN               NaN                 NaN
# 75%                  NaN               NaN                 NaN
# max                  NaN               NaN                 NaN
#
#        tipo_de_pago_mas_usado  ingresos_mensuales
# count                   30000        30000.000000
# unique                      4                 NaN
# top                  Efectivo                 NaN
# freq                    11813                 NaN
# mean                      NaN         5389.755867
# std                       NaN         4538.491728
# min                       NaN          800.000000
# 25%                       NaN         1860.000000
# 50%                       NaN         3402.000000
# 75%                       NaN         7761.000000
# max                       NaN        17999.000000

# %%
columnas_innecesarias = [
    'id_persona', 'nombre', 'apellido', 'telefono_contacto', 'correo_electronico'
]

df.drop(columns=columnas_innecesarias, inplace=True)

# %%
df.columns
# Out:
# Index(['edad', 'genero', 'ciudad_residencia', 'estrato_socioeconomico',
#        'frecuencia_visita', 'promedio_gasto_comida', 'ocio', 'consume_licor',
#        'preferencias_alimenticias', 'membresia_premium',
#        'tipo_de_pago_mas_usado', 'ingresos_mensuales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   edad                       29899 non-null  float64
#  1   genero                     30000 non-null  object
#  2   ciudad_residencia          30000 non-null  object
#  3   estrato_socioeconomico     30000 non-null  object
#  4   frecuencia_visita          30000 non-null  int64
#  5   promedio_gasto_comida      29855 non-null  float64
#  6   ocio                       30000 non-null  object
#  7   consume_licor              30000 non-null  object
#  8   preferencias_alimenticias  28597 non-null  object
#  9   membresia_premium          30000 non-null  object
#  10  tipo_de_pago_mas_usado     30000 non-null  object
#  11  ingresos_mensuales         30000 non-null  int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 2.7+ MB

# %%
# Conteo de nulos por variable
df.isnull().sum().sort_values(ascending=False)
# Out:
# preferencias_alimenticias    1403
# promedio_gasto_comida         145
# edad                          101
# genero                          0
# estrato_socioeconomico          0
# ciudad_residencia               0
# ocio                            0
# frecuencia_visita               0
# consume_licor                   0
# membresia_premium               0
# tipo_de_pago_mas_usado          0
# ingresos_mensuales              0
# dtype: int64

# %%
# Graficación del porcentaje de nulos
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
plt.title('Porcentaje de Valores Nulos por Variable')
plt.xlabel('Variables')
plt.ylabel('Porcentaje de Valores Nulos')
# Out:
# Text(0, 0.5, 'Porcentaje de Valores Nulos')

# %%
df.describe(include='all').transpose()
# Out:
#                              count unique       top   freq         mean  \
# edad                       29899.0    NaN       NaN    NaN    49.665006
# genero                       30000      2  Femenino  15044          NaN
# ciudad_residencia            30000     10   Chicago   5384          NaN
# estrato_socioeconomico       30000      4     Medio   9325          NaN
# frecuencia_visita          30000.0    NaN       NaN    NaN     3.896133
# promedio_gasto_comida      29855.0    NaN       NaN    NaN    32.603452
# ocio                         30000      2        No  15094          NaN
# consume_licor                30000      2        Sí  18483          NaN
# preferencias_alimenticias    28597      6    Carnes   7916          NaN
# membresia_premium            30000      2        No  17155          NaN
# tipo_de_pago_mas_usado       30000      4  Efectivo  11813          NaN
# ingresos_mensuales         30000.0    NaN       NaN    NaN  5389.755867
#
#                                    std    min     25%     50%     75%      max
# edad                          23.83955   -5.0    33.0    49.0    65.0    300.0
# genero                             NaN    NaN     NaN     NaN     NaN      NaN
# ciudad_residencia                  NaN    NaN     NaN     NaN     NaN      NaN
# estrato_socioeconomico             NaN    NaN     NaN     NaN     NaN      NaN
# frecuencia_visita             2.741532   -3.0     2.0     4.0     5.0     10.0
# promedio_gasto_comida        26.402601    0.0   13.29   25.51    44.4   149.97
# ocio                               NaN    NaN     NaN     NaN     NaN      NaN
# consume_licor                      NaN    NaN     NaN     NaN     NaN      NaN
# preferencias_alimenticias          NaN    NaN     NaN     NaN     NaN      NaN
# membresia_premium                  NaN    NaN     NaN     NaN     NaN      NaN
# tipo_de_pago_mas_usado             NaN    NaN     NaN     NaN     NaN      NaN
# ingresos_mensuales         4538.491728  800.0  1860.0  3402.0  7761.0  17999.0

# %%
# Distribucion de variables numericas
df.select_dtypes(include=np.number).hist(bins=30, figsize=(15,10))
plt.suptitle('Distribucion de variables numericas')
plt.show()

# %%
# Boxplot para detectar outliers o datos atipicos
num_cols = ['edad', 'frecuencia_visita', 'promedio_gasto_comida', 'ingresos_mensuales']
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Columnas y sus respectivos valores
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
  print(f"Columna {col}")
  print(df[col].value_counts(dropna=False))
# Out:
# Columna genero
# genero
# Femenino     15044
# Masculino    14956
# Name: count, dtype: int64
# Columna ciudad_residencia
# ciudad_residencia
# Chicago      5384
# NYC          4769
# Miami        3186
# San Diego    3075
# Dallas       2602
# Boston       2547
# Denver       2523
# Houston      2212
# Seattle      2191
# Phoenix      1511
# Name: count, dtype: int64
# Columna estrato_socioeconomico
# estrato_socioeconomico
# Medio       9325
# Alto        9038
# Bajo        6161
# Muy Alto    5476
# Name: count, dtype: int64
# Columna ocio
# ocio
# No    15094
# Sí    14906
# Name: count, dtype: int64
# Columna consume_licor
# consume_licor
# Sí    18483
# No    11517
# Name: count, dtype: int64
# Columna preferencias_alimenticias
# preferencias_alimenticias
# Carnes         7916
# Vegetariano    6580
# Mariscos       5212
# Vegano         3267
# Pescado        2983
# Otro           2639
# NaN            1403
# Name: count, dtype: int64
# Columna membresia_premium
# membresia_premium
# No    17155
# Sí    12845
# Name: count, dtype: int64
# Columna tipo_de_pago_mas_usado
# tipo_de_pago_mas_usado
# Efectivo        11813
# Tarjeta          9954
# App              7678
# Criptomoneda      555
# Name: count, dtype: int64

# %% [markdown]
# ### Eliminacion de outliers

# %%
# Edades negativas o absurdas
df['edad'] = df['edad'].apply(lambda x: x if (x is not None and 18 <= x <= 80) else np.nan)

# Frecuencia de visitas absurdas
df['frecuencia_visita'] = df['frecuencia_visita'].apply(lambda x: x if (x is not None and 0 <= x <= 15) else np.nan)

# %%
# Distribucion de variables numericas
df.select_dtypes(include=np.number).hist(bins=30, figsize=(15,10))
plt.suptitle('Distribucion de variables numericas')
plt.show()

# %% [markdown]
# ### Imputacion de datos nulos

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

columnas_numericas = ['edad', 'frecuencia_visita', 'promedio_gasto_comida', 'ingresos_mensuales']

df_numerico = df[columnas_numericas]

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_numerico)

imputer = KNNImputer(n_neighbors=5)
df_imputedo_scaled = imputer.fit_transform(df_scaled)

df_imputado = scaler.inverse_transform(df_imputedo_scaled)
df[columnas_numericas] = pd.DataFrame(df_imputado, columns=columnas_numericas)

# %%
df['preferencias_alimenticias'].value_counts(dropna=False)
# Out:
# preferencias_alimenticias
# Carnes         7916
# Vegetariano    6580
# Mariscos       5212
# Vegano         3267
# Pescado        2983
# Otro           2639
# NaN            1403
# Name: count, dtype: int64

# %%
df['preferencias_alimenticias'] = df['preferencias_alimenticias'].fillna('Otro')

# %%
df = df.astype({
    'edad': 'int',
    'frecuencia_visita': 'int',
    'promedio_gasto_comida': 'float',
    'ingresos_mensuales': 'float'
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   edad                       30000 non-null  int64
#  1   genero                     30000 non-null  object
#  2   ciudad_residencia          30000 non-null  object
#  3   estrato_socioeconomico     30000 non-null  object
#  4   frecuencia_visita          30000 non-null  int64
#  5   promedio_gasto_comida      30000 non-null  float64
#  6   ocio                       30000 non-null  object
#  7   consume_licor              30000 non-null  object
#  8   preferencias_alimenticias  30000 non-null  object
#  9   membresia_premium          30000 non-null  object
#  10  tipo_de_pago_mas_usado     30000 non-null  object
#  11  ingresos_mensuales         30000 non-null  float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 2.7+ MB

# %% [markdown]
# ### Analisis multivariable

# %%
df['promedio_gasto_total_mes'] = df['frecuencia_visita'] * df['promedio_gasto_comida']
city_gasto = df.groupby('ciudad_residencia')['promedio_gasto_total_mes'].mean().sort_values()

city_gasto.plot(kind='bar', figsize=(10, 6))
plt.title('Gasto promedio por mes por ciudad')
plt.xlabel('Ciudad')
plt.ylabel('Gasto promedio')
plt.show()

# %%
# Gasto promedio genero al mes
genero_gasto = df.groupby('genero')['promedio_gasto_total_mes'].mean().sort_values()
genero_gasto.plot(kind='bar', figsize=(10, 6))
plt.title('Gasto promedio por mes por genero')
plt.xlabel('Genero')
plt.ylabel('Gasto promedio')
plt.show()

# %%
# Gasto promedio por estrato socioeconomico al mes
estrato_gasto = df.groupby('estrato_socioeconomico')['promedio_gasto_total_mes'].mean().sort_values()
estrato_gasto.plot(kind='bar', figsize=(10,10))
plt.title('Gasto promedio por mes por estrato socioeconomico')
plt.xlabel('Estrato socioeconomico')
plt.ylabel('Gasto promedio')
plt.show()

# %%
# Segmentos por frecuencia y gasto
sns.scatterplot(data=df, x='frecuencia_visita', y='promedio_gasto_comida', hue='estrato_socioeconomico')
plt.title('Segmentos por frecuencia y gasto')
plt.show()

# %%
# Gasto vs ingreso por estrato
sns.boxplot(data=df, x='estrato_socioeconomico', y='ingresos_mensuales')
plt.title('Gasto vs ingreso por estrato')
plt.show()

# %%
#Preferencias alimenticias por ciudad
pref_ciudad = pd.crosstab(df['ciudad_residencia'], df['preferencias_alimenticias'], normalize='index')
pref_ciudad.plot(kind='bar', staked=True,figsize=(10, 6))
plt.title('Preferencias alimenticias por ciudad')
plt.xlabel('Ciudad')
plt.ylabel('Porcentaje')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4276037359.py in <cell line: 0>()
#       1 #Preferencias alimenticias por ciudad
#       2 pref_ciudad = pd.crosstab(df['ciudad_residencia'], df['preferencias_alimenticias'], normalize='index')
# ----> 3 pref_ciudad.plot(kind='bar', staked=True,figsize=(10, 6))
#       4 plt.title('Preferencias alimenticias por ciudad')
#       5 plt.xlabel('Ciudad')
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     499         self._compute_plot_data()
#     500         fig = self.fig
# --> 501         self._make_plot(fig)
#     502         self._add_table()
#     503         self._make_legend()
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self, fig)
#    1946             else:
#    1947                 w = self.bar_width / K
# -> 1948                 rect = self._plot(
#    1949                     ax,
#    1950                     self.ax_pos + (i + 0.5) * w,
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1876         **kwds,
#    1877     ):
# -> 1878         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1879
#    1880     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2641                 hatch=htch,
#    2642                 )
# -> 2643             r._internal_update(kwargs)
#    2644             r.get_path()._interpolation_steps = 100
#    2645             if orientation == 'vertical':
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1231         The lack of prenormalization is to maintain backcompatibility.
#    1232         """
# -> 1233         return self._update_props(
#    1234             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235             "{prop_name!r}")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1204                     func = getattr(self, f"set_{k}", None)
#    1205                     if not callable(func):
# -> 1206                         raise AttributeError(
#    1207                             errfmt.format(cls=type(self), prop_name=k),
#    1208                             name=k)
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'staked'

# %%
# Perfil del cliente de alto gasto
threshhold = df['promedio_gasto_total_mes'].quantile(0.9)
high_gasto = df[df['promedio_gasto_total_mes'] >= threshhold]
high_gasto.describe(include='all')
# Out:
#                edad    genero ciudad_residencia estrato_socioeconomico  \
# count   3000.000000      3000              3000                   3000
# unique          NaN         2                10                      2
# top             NaN  Femenino               NYC               Muy Alto
# freq            NaN      1562               516                   2881
# mean      48.463333       NaN               NaN                    NaN
# std       18.232502       NaN               NaN                    NaN
# min       18.000000       NaN               NaN                    NaN
# 25%       33.000000       NaN               NaN                    NaN
# 50%       48.000000       NaN               NaN                    NaN
# 75%       64.000000       NaN               NaN                    NaN
# max       80.000000       NaN               NaN                    NaN
#
#         frecuencia_visita  promedio_gasto_comida  ocio consume_licor  \
# count         3000.000000            3000.000000  3000          3000
# unique                NaN                    NaN     2             2
# top                   NaN                    NaN    Sí            Sí
# freq                  NaN                    NaN  1526          1889
# mean             7.811000              89.576912   NaN           NaN
# std              1.610428              22.966007   NaN           NaN
# min              5.000000              42.440000   NaN           NaN
# 25%              6.000000              72.087500   NaN           NaN
# 50%              8.000000              88.310000   NaN           NaN
# 75%              9.000000             104.067500   NaN           NaN
# max             10.000000             149.970000   NaN           NaN
#
#        preferencias_alimenticias membresia_premium tipo_de_pago_mas_usado  \
# count                       3000              3000                   3000
# unique                         6                 2                      4
# top                       Carnes                Sí               Efectivo
# freq                         757              2840                   1198
# mean                         NaN               NaN                    NaN
# std                          NaN               NaN                    NaN
# min                          NaN               NaN                    NaN
# 25%                          NaN               NaN                    NaN
# 50%                          NaN               NaN                    NaN
# 75%                          NaN               NaN                    NaN
# max                          NaN               NaN                    NaN
#
#         ingresos_mensuales  promedio_gasto_total_mes
# count          3000.000000               3000.000000
# unique                 NaN                       NaN
# top                    NaN                       NaN
# freq                   NaN                       NaN
# mean          13227.862667                690.151461
# std            2879.393934                209.997511
# min            3503.000000                422.450000
# 25%           11007.750000                521.197500
# 50%           13387.500000                642.640000
# 75%           15530.500000                814.837500
# max           17998.000000               1499.700000

# %%
# Distribucion de membresia por estrato
sns.countplot(data=df, x='estrato_socioeconomico', hue='membresia_premium')
plt.title('Membresias Premium por Estrado Socioeconomico')
plt.show()

# %%
# Porcentaje de membresias por ciudad
membresia_ciudad = df.groupby('ciudad_residencia')['membresia_premium'].value_counts(normalize=True).unstack()
membresia_ciudad['Sí'].sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
plt.title('Porcentaje de membresias premium por ciudad')
plt.xlabel('Ciudad')
plt.ylabel('Porcentaje')
plt.show()

# %%
# Boxplot ingresos vs membresia
sns.boxplot(data=df, x='membresia_premium', y='ingresos_mensuales')
plt.title('Ingresos vs membresia')
plt.show()

# %%
# Boxplot de frecuencia de visita con respecto a si tienen membresia premium en algun restaurante
sns.boxplot(data=df, x='membresia_premium', y='frecuencia_visita')
plt.title('Frecuencia de Visita con Membresia Premium')
plt.show()

# %%
# Crosstab preferencias alimenticias
pd.crosstab(df['preferencias_alimenticias'], df['membresia_premium'], normalize='index') * 100
# Out:
# membresia_premium                 No         Sí
# preferencias_alimenticias
# Carnes                     59.183931  40.816069
# Mariscos                   55.890253  44.109747
# Otro                       57.644730  42.355270
# Pescado                    57.626550  42.373450
# Vegano                     57.055403  42.944597
# Vegetariano                55.379939  44.620061

# %%
# Consumo de licor por edades
df['grupo_edad'] = pd.cut(df['edad'], bins=[17, 30, 55, 70, 100], labels=['18-30', '31-55', '56-70', '71+'])
alcohol_por_edad = df.groupby('grupo_edad')['consume_licor'].value_counts(normalize=True).unstack()
alcohol_por_edad.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Consumo de licor por edades')
plt.xlabel('Edad')
plt.ylabel('Porcentaje')
plt.show()
# Out:
# /tmp/ipython-input-2803838621.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   alcohol_por_edad = df.groupby('grupo_edad')['consume_licor'].value_counts(normalize=True).unstack()
